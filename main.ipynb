# %%
import pandas as pd
import numpy as np
from sklearn.kernel_approximation import RBFSampler
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv('data/data.csv')
data['date'] = pd.to_datetime(data['yyyymm'].astype(str), format='%Y%m')
data['Index'] = data['Index'].str.replace(',', '').astype(float)
data['returns'] = data['Index'].pct_change().shift(-1)
data = data.drop(columns=['yyyymm'])
data = data[['date'] + [col for col in data.columns if col != 'date']]
data = data[data['date'] >= '1926-01-01']
data = data.set_index('date')
data.head()
# Out:
#             Index     D12    E12       b/m     tbl     AAA     BAA     lty  \
# date
# 1926-01-01  12.74  0.6075  1.249  0.387671  0.0349  0.0482  0.0609  0.0374
# 1926-02-01  12.18  0.6150  1.248  0.394363  0.0318  0.0477  0.0602  0.0372
# 1926-03-01  11.46  0.6225  1.248  0.494091  0.0314  0.0479  0.0605  0.0371
# 1926-04-01  11.72  0.6300  1.247  0.482917  0.0308  0.0474  0.0598  0.0368
# 1926-05-01  11.81  0.6375  1.246  0.483860  0.0317  0.0471  0.0586  0.0369
#
#             ntis     Rfree      infl     ltr   corpr      svar  csp  \
# date
# 1926-01-01   NaN  0.002925  0.000000  0.0138  0.0072  0.000857  NaN
# 1926-02-01   NaN  0.002908  0.000000  0.0063  0.0045  0.001099  NaN
# 1926-03-01   NaN  0.002650 -0.005587  0.0041  0.0084  0.006016  NaN
# 1926-04-01   NaN  0.002617  0.005618  0.0076  0.0097  0.001466  NaN
# 1926-05-01   NaN  0.002567 -0.005587  0.0014  0.0044  0.000690  NaN
#
#             CRSP_SPvw  CRSP_SPvwx   returns
# date
# 1926-01-01  -0.001783   -0.003980 -0.043956
# 1926-02-01  -0.033296   -0.037876 -0.059113
# 1926-03-01  -0.057708   -0.062007  0.022688
# 1926-04-01   0.038522    0.034856  0.007679
# 1926-05-01   0.013623    0.009070  0.043184

# %%
data[['csp', 'ntis']] = data[['csp', 'ntis']].interpolate(method='time')
data[['csp', 'ntis']] = data[['csp', 'ntis']].ffill()
data.dropna(inplace=True)
data.head()
# Out:
#             Index     D12     E12       b/m     tbl     AAA     BAA     lty  \
# date
# 1937-05-01  16.26  0.8100  1.1500  0.489382  0.0041  0.0333  0.0484  0.0282
# 1937-06-01  15.40  0.8400  1.1700  0.504961  0.0036  0.0328  0.0493  0.0285
# 1937-07-01  16.98  0.8167  1.1867  0.464649  0.0028  0.0325  0.0491  0.0277
# 1937-08-01  16.04  0.7933  1.2033  0.481935  0.0029  0.0324  0.0492  0.0286
# 1937-09-01  13.76  0.7700  1.2200  0.553147  0.0031  0.0328  0.0516  0.0284
#
#                 ntis   Rfree      infl     ltr   corpr      svar       csp  \
# date
# 1937-05-01  0.028278  0.0006  0.006993  0.0053  0.0040  0.003593  0.003398
# 1937-06-01  0.031266  0.0003  0.000000 -0.0018  0.0053  0.002984  0.004206
# 1937-07-01  0.027225  0.0003  0.006944  0.0138  0.0039  0.002982  0.003630
# 1937-08-01  0.031064  0.0002  0.000000 -0.0104 -0.0017  0.002141  0.003325
# 1937-09-01  0.035847  0.0004  0.006897  0.0045  0.0025  0.015821  0.003339
#
#             CRSP_SPvw  CRSP_SPvwx   returns
# date
# 1937-05-01  -0.005699   -0.011686 -0.052891
# 1937-06-01  -0.053803   -0.057853  0.102597
# 1937-07-01   0.098991    0.098012 -0.055359
# 1937-08-01  -0.051183   -0.056291 -0.142145
# 1937-09-01  -0.139610   -0.143683 -0.101744

# %%
# Interpolate missing values using time-based interpolation
data[['csp', 'ntis']] = data[['csp', 'ntis']].interpolate(method='time')
data[['csp', 'ntis']] = data[['csp', 'ntis']].ffill()
data.dropna(inplace=True)
data.head()
# Out:
#             Index     D12     E12       b/m     tbl     AAA     BAA     lty  \
# date
# 1937-05-01  16.26  0.8100  1.1500  0.489382  0.0041  0.0333  0.0484  0.0282
# 1937-06-01  15.40  0.8400  1.1700  0.504961  0.0036  0.0328  0.0493  0.0285
# 1937-07-01  16.98  0.8167  1.1867  0.464649  0.0028  0.0325  0.0491  0.0277
# 1937-08-01  16.04  0.7933  1.2033  0.481935  0.0029  0.0324  0.0492  0.0286
# 1937-09-01  13.76  0.7700  1.2200  0.553147  0.0031  0.0328  0.0516  0.0284
#
#                 ntis   Rfree      infl     ltr   corpr      svar       csp  \
# date
# 1937-05-01  0.028278  0.0006  0.006993  0.0053  0.0040  0.003593  0.003398
# 1937-06-01  0.031266  0.0003  0.000000 -0.0018  0.0053  0.002984  0.004206
# 1937-07-01  0.027225  0.0003  0.006944  0.0138  0.0039  0.002982  0.003630
# 1937-08-01  0.031064  0.0002  0.000000 -0.0104 -0.0017  0.002141  0.003325
# 1937-09-01  0.035847  0.0004  0.006897  0.0045  0.0025  0.015821  0.003339
#
#             CRSP_SPvw  CRSP_SPvwx   returns
# date
# 1937-05-01  -0.005699   -0.011686 -0.052891
# 1937-06-01  -0.053803   -0.057853  0.102597
# 1937-07-01   0.098991    0.098012 -0.055359
# 1937-08-01  -0.051183   -0.056291 -0.142145
# 1937-09-01  -0.139610   -0.143683 -0.101744

# %%
features = data.drop(columns=['returns'])  # Exclude 'returns' from transformation
target = data['returns']  # Keep 'returns' as the label
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)
rff = RBFSampler(gamma=1.0, n_components=1000, random_state=42)
rff_features = rff.fit_transform(scaled_features)
rff_df = pd.DataFrame(rff_features, columns=[f'RFF_{i}' for i in range(1, 1001)])

# %%
X = rff_df.values
Y = data['returns'].values
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

beta = np.linalg.lstsq(X_train, Y_train, rcond=None)[0]
Y_train_pred = X_train @ beta
Y_test_pred = X_test @ beta
predictions_df = pd.DataFrame({
    'Actual_Test_Returns': Y_test,
    'Predicted_Test_Returns': Y_test_pred
})

# %%
predictions_df
positions = np.sign(Y_test_pred)  # +1 if predict up, -1 if predict down
pnl = positions * Y_test  # PnL per period (based on actual returns)
cumulative_pnl = np.cumsum(pnl)  # Cumulative sum to track total performance
trading_results = pd.DataFrame({
    'Actual_Returns': Y_test,
    'Predicted_Returns': Y_test_pred,
    'Positions': positions,
    'PnL': pnl,
    'Cumulative_PnL': cumulative_pnl
})
trading_results
# Out:
#      Actual_Returns  Predicted_Returns  Positions       PnL  Cumulative_PnL
# 0          0.048520          -0.041468       -1.0 -0.048520       -0.048520
# 1          0.038595           0.034079        1.0  0.038595       -0.009925
# 2          0.035464          -0.014812       -1.0 -0.035464       -0.045390
# 3         -0.035228          -0.066418       -1.0  0.035228       -0.010162
# 4          0.110364          -0.169709       -1.0 -0.110364       -0.120525
# ..              ...                ...        ...       ...             ...
# 203       -0.067654           0.053643        1.0 -0.067654        0.126351
# 204        0.014759           0.132517        1.0  0.014759        0.141111
# 205       -0.057446          -0.215065       -1.0  0.057446        0.198556
# 206        0.021417           0.154747        1.0  0.021417        0.219973
# 207        0.010091           0.044601        1.0  0.010091        0.230064
#
# [208 rows x 5 columns]

# %%
exc_ret = trading_results['Cumulative_PnL'] - 0.03
sharp_ratio = np.mean(exc_ret) / np.std(exc_ret)
sharp_ratio
# Out:
# -0.2331307341522288
